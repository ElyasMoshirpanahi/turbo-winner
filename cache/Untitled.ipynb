# %%
from glob import glob as g
import json

for i in g("*.json"):
    file = open(i).read()
    print(json.loads(file)['hamster_url'],"\n"*10)
# Out:
# https://app.hamsterkombat.io/clicker/?tgWebAppStartParam=kentId80741935#tgWebAppData=user%3D%257B%2522id%2522%253A161627205%252C%2522first_name%2522%253A%2522D_M%2522%252C%2522last_name%2522%253A%2522%2522%252C%2522username%2522%253A%2522Dr_Moshiri_Nika%2522%252C%2522language_code%2522%253A%2522en%2522%252C%2522allows_write_to_pm%2522%253Atrue%257D%26chat_instance%3D-7522786569210500813%26chat_type%3Dprivate%26start_param%3DkentId80741935%26auth_date%3D1718272223%26hash%3D5b7c06b328dceadd9cd9764d2ba94454b472afa655605f3b81f450dd575e2d57&tgWebAppVersion=7.4&tgWebAppPlatform=ios
#
#
#
#
#
#
#
#
#
#
# ...
